# %% [markdown]
# ### Empirical Example Three for RobustiPy!
#
# #### This example is designed to show how the OLSRobust class can be used to estimate a model with longitudinal data.
#
# To get access to this data, you'll need the Understanding Society: Longitudinal Teaching Dataset, Waves 1-9, 2009-2018 from [[here](https://beta.ukdataservice.ac.uk/datacatalogue/studies/study?id=8715#!/access-data)]. Registration is immediate for this. Documentation which accompanies it can be found [[here](https://doc.ukdataservice.ac.uk/doc/8715/mrdoc/pdf/8715_user_guide.pdf)].
#
# You want to put this data somewhere like `.data/input`.
#
# As always, lets load in some of the libraries which we'll need:

# %%
import os
import numpy as np
import pandas as pd
from robustipy.models import OLSRobust

# %% [markdown]
# Then, load in the dataset (note: we are using the tab-seperated version, but they should all be equivilent):

# %%
df = pd.read_csv(os.path.join(os.getcwd(),
                              'data',
                              'input',
                              'longitudinal_td.tab'), sep='\t',
                 low_memory=False)
df['pidp'] = df['pidp'].astype(int)
#df['pidp'] = pd.to_numeric(df['pidp'], errors='raise')
df.dtypes
# Out:
# pidp           int64
# wave           int64
# hidp           int64
# buno_dv        int64
# intdatd_dv    object
#                ...
# envhabit7     object
# envhabit8     object
# envhabit9     object
# envhabit10    object
# envhabit11    object
# Length: 148, dtype: object

# %% [markdown]
# Let's quickly eyeball the data to see what we have:

# %%
df.head(5)
# Out:
#        pidp  wave      hidp  buno_dv intdatd_dv intdatm_dv intdaty_dv  \
# 0  68001367     1  68001363        1         19          1       2009
# 1  68004087     1  68004083        1          8          1       2009
# 2  68004087     2  68013602        1         16          2       2010
# 3  68004087     3  68013604        1          9          2       2011
# 4  68004087     4  68013606        1         24          1       2012
#
#    indmode  numintd_dv  hhorig  ...  envhabit2  envhabit3  envhabit4  \
# 0        1           1       1  ...          2          4          4
# 1        1           9       1  ...          1          5          1
# 2        1           9       1  ...
# 3        1           9       1  ...
# 4        1           9       1  ...          1          5          1
#
#   envhabit5 envhabit6 envhabit7 envhabit8 envhabit9 envhabit10 envhabit11
# 0         4         3         3         3         1          5          1
# 1         3         2         1         5         3          4          6
# 2
# 3
# 4         5         3         1         6         2          5          6
#
# [5 rows x 148 columns]

# %% [markdown]
# Our main dependent variable of interest is sf1_dv: General health.

# %%
df['sf1_dv'] = pd.to_numeric(df['sf1_dv'], errors='coerce')

# %% [markdown]
# Then, we're going to binarise it so that good health is 3 or more (==1), zero otherwise:

# %%
df = df[df['sf1_dv']>0]
df['sf1_dv_good'] = np.where(df['sf1_dv']>=3, 1, 0)

# %% [markdown]
# Let's convert our `sex_dv` variable into binary 1s and zeros:

# %%
df['sex_dv'] = pd.to_numeric(df['sex_dv'], errors='coerce')
df['sex_dv'] = np.where(df['sex_dv']==2, 1, 0)
df['sex_dv'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Let's do something similar for cohab_dv, but this is already 1s and 0s:

# %%
df['cohab_dv'] = pd.to_numeric(df['cohab_dv'], errors='coerce')
df = df[df['cohab_dv']>=0]

# %%
df['urban_dv'] = pd.to_numeric(df['urban_dv'], errors='coerce')
df = df[df['urban_dv']>0]
df['urban_dv'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Lets then – for simplicity and without failing to appreciate the complexity of this variable – dichotomize an additional variable (after cleaning it for missing/non-response). You can make something as simple as `is_british` (==1, 0 otherwise), or something more elaborate.

# %%
df['ethn_dv'] = pd.to_numeric(df['ethn_dv'], errors='coerce')
df = df[df['ethn_dv']>0]
df['is_british'] = np.where(df['ethn_dv']==1, 1, 0)

# %%
df = df[df['hhsize_dv']>0]

# %%
df['age_dv'] = pd.to_numeric(df['age_dv'], errors='coerce')
df = df[df['age_dv']>0]

# %% [markdown]
# Let's next make a variable for whether an individual has a degree or not:

# %%
df['hiqual_dv'] = pd.to_numeric(df['hiqual_dv'], errors='coerce')
df = df[df['hiqual_dv']>0]
df['has_degree'] = np.where(df['hiqual_dv']==3, 1, 0)

# %%
df['jbstat'] = pd.to_numeric(df['jbstat'], errors='coerce')
df = df[df['jbstat']>0]
df['jbstat'] = np.where(df['jbstat']<=2, 1, 0)

# %%
df['jbstat'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Subset our dataframe for simplicity:

# %%
df = df.reset_index()
df = df[['sf1_dv_good', 'age_dv', 'sex_dv', 'cohab_dv', 'pidp', 'is_british', 'urban_dv', 'hhsize_dv', 'has_degree', 'jbstat']]
df.head(5)
# Out:
#    sf1_dv_good  age_dv  sex_dv  cohab_dv      pidp  is_british  urban_dv  \
# 0            0    39.0       0         0  68001367           1       1.0
# 1            0    59.0       0         0  68004087           0       1.0
# 2            0    60.0       0         0  68004087           0       1.0
# 3            0    61.0       0         0  68004087           0       1.0
# 4            0    62.0       0         0  68004087           0       1.0
#
#    hhsize_dv  has_degree  jbstat
# 0          1           1       1
# 1          1           0       1
# 2          1           0       1
# 3          1           0       1
# 4          1           0       1

# %% [markdown]
# What's the length?

# %%
len(df)
# Out:
# 189858

# %% [markdown]
# Now let's drop and see if we lose any (we shouldnt, though! Why?)

# %%
df = df.dropna()
print(len(df))
# Out:
# 189858

# %% [markdown]
# Now what does our dataset look like?

# %%
df.head(5)
# Out:
#    sf1_dv_good  age_dv  sex_dv  cohab_dv      pidp  is_british  urban_dv  \
# 0            0    39.0       0         0  68001367           1       1.0
# 1            0    59.0       0         0  68004087           0       1.0
# 2            0    60.0       0         0  68004087           0       1.0
# 3            0    61.0       0         0  68004087           0       1.0
# 4            0    62.0       0         0  68004087           0       1.0
#
#    hhsize_dv  has_degree  jbstat
# 0          1           1       1
# 1          1           0       1
# 2          1           0       1
# 3          1           0       1
# 4          1           0       1

# %% [markdown]
# Lets quickly check the correlation matrix to check that nothing funky is going on:

# %%
df.corr()
# Out:
#              sf1_dv_good    age_dv    sex_dv  cohab_dv      pidp  is_british  \
# sf1_dv_good     1.000000  0.196541 -0.003253 -0.032659  0.000109    0.003224
# age_dv          0.196541  1.000000 -0.041374 -0.205489  0.004652    0.231569
# sex_dv         -0.003253 -0.041374  1.000000 -0.007806 -0.007919   -0.004091
# cohab_dv       -0.032659 -0.205489 -0.007806  1.000000 -0.006143    0.063252
# pidp            0.000109  0.004652 -0.007919 -0.006143  1.000000   -0.025526
# is_british      0.003224  0.231569 -0.004091  0.063252 -0.025526    1.000000
# urban_dv       -0.031297  0.127629  0.006577 -0.021351 -0.031089    0.182263
# hhsize_dv      -0.104842 -0.468516  0.024336  0.077753  0.014131   -0.221361
# has_degree     -0.020147 -0.131951 -0.065422  0.025600  0.003348    0.019640
# jbstat         -0.208361 -0.460570 -0.064780  0.125091 -0.012890   -0.045136
#
#              urban_dv  hhsize_dv  has_degree    jbstat
# sf1_dv_good -0.031297  -0.104842   -0.020147 -0.208361
# age_dv       0.127629  -0.468516   -0.131951 -0.460570
# sex_dv       0.006577   0.024336   -0.065422 -0.064780
# cohab_dv    -0.021351   0.077753    0.025600  0.125091
# pidp        -0.031089   0.014131    0.003348 -0.012890
# is_british   0.182263  -0.221361    0.019640 -0.045136
# urban_dv     1.000000  -0.052494   -0.008296 -0.026722
# hhsize_dv   -0.052494   1.000000    0.058772  0.230737
# has_degree  -0.008296   0.058772    1.000000  0.062721
# jbstat      -0.026722   0.230737    0.062721  1.000000

# %% [markdown]
# What data types do we have here?

# %%
df.dtypes
# Out:
# sf1_dv_good      int64
# age_dv         float64
# sex_dv           int64
# cohab_dv         int64
# pidp             int64
# is_british       int64
# urban_dv       float64
# hhsize_dv        int64
# has_degree       int64
# jbstat           int64
# dtype: object

# %% [markdown]
# Finally, lets call RobustiPy as we do in other examples, noting the group='pipd' call:

# %%
ukhls_robustipy = OLSRobust(y=['sf1_dv_good'],
                            x=['age_dv'],
                            data=df.dropna())

# %% [markdown]
# Now, let's fit the model:

# %%
ukhls_robustipy.fit(controls=['cohab_dv',
                              'sex_dv',
                              'is_british',
                              'urban_dv',
                              'hhsize_dv',
                              'has_degree',
                              'jbstat'
                             ],
                   draws=1000,
                   kfold=10,
                   group='pidp'
                   )
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# And, get the results:

# %%
ukhls_results = ukhls_robustipy.get_results()

# %% [markdown]
# Plot results:

# %%
ukhls_results.plot(ic='hqic',
                   figsize=(16, 16),
                   specs=[['sex_dv', 'urban_dv'], ['jbstat', 'hhsize_dv'], ['cohab_dv']],
                   project_name='ukhls_example',
                   ext='pdf'
                   )

# %% [markdown]
# And print the summary statistic:

# %%
ukhls_results.summary()
# Out:
# ==============================
# 1. Model Summary
# ==============================
# Model: OLS Robust
# Inference Tests: Yes
# Dependent variable: sf1_dv_good
# Independent variable: age_dv
# Number of possible controls: 7
# Number of draws: 1000
# Number of folds: 10
# Number of specifications: 128
# ==============================
# 2.Model Robustness Metrics
# ==============================
# 2.1 Inference Metrics
# ==============================
# Median beta (all specifications, no resampling): 0.012064144896338573 (p-value: 0.0)
# Median beta (all bootstraps and specifications): 0.01206619247876516
# Min beta (all specifications, no resampling): 0.011976694258317318
# Min beta (all bootstraps and specifications): 0.011846649949866773
# Max beta (all specifications, no resampling): 0.012153569127281312
# Max beta (all bootstraps and specifications): 0.01196473652171446
# Significant portion of beta (all specifications, no resampling): 1.0 (p-value: 0.0)
# Significant portion of beta (all bootstraps and specifications): 1.0
# Positive portion of beta (all specifications, no resampling): 1.0 (p-value: 0.0)
# Positive portion of beta (all bootstraps and specifications): 1.0
# Negative portion of beta (all specifications, no resampling): 0.0 (p-value: 1.0)
# Negative portion of beta (all bootstraps and specifications): 0.0
# Positive and Significant portion of beta (all specifications, no resampling): 1.0 (p-value: 0.0)
# Positive and Significant portion of beta (all bootstraps and specifications): 1.0
# Negative and Significant portion of beta (all specifications, no resampling): 0.0 (p-value: 0.0)
# Negative and Significant portion of beta (all bootstraps and specifications): 0.0
# Stouffer's Z-score test: inf, 0.0
# ==============================
# 2.1 In-Sample Metrics (Full Sample)
# ==============================
# Min AIC: 480831.02281028224,Specs: ['cohab_dv', 'jbstat', 'hhsize_dv', 'urban_dv', 'has_degree']
# Min BIC: 101161.84691336045, Specs: ['jbstat']
# Min HQIC: 101136.81783155553, Specs: ['jbstat', 'hhsize_dv']
# Max Log Likelihood: -50557.51140514112, Specs: ['cohab_dv', 'jbstat', 'hhsize_dv', 'urban_dv', 'has_degree']
# Min Log Likelihood: -50570.349884502706, Specs: []
# Max R2: 0.007524110155146868, Specs: ['jbstat', 'has_degree', 'hhsize_dv']
# Min R2: 0.007394379672804652, Specs: ['cohab_dv', 'urban_dv', 'sex_dv', 'is_british']
# ==============================
# 2.2 Out-Of-Sample Metrics (r-squared averaged across folds)
# ==============================
# Max Average: 0.00749706515569275, Specs: ['jbstat', 'hhsize_dv']
# Min Average: 0.007352425691312114, Specs: ['cohab_dv', 'urban_dv', 'sex_dv', 'has_degree']
# Mean Average: 0.007423028355206997
# Median Average: 0.00742211618304785
