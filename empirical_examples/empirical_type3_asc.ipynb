# %% [markdown]
# ### Empirical Example for RobustiPY (Type 3)!
#
# #### This example is designed to show how the OLSRobust class can be used to estimate a model with longitudinal data _and_ a set of specific, constant x-variables.
#
# Specifically, it represents an Adult Social Care (ASC) example from Zhang, Bennett and Yeandle published in the BMJ Open. You can find that paper [here](https://bmjopen.bmj.com/content/11/12/e049652). Unfortunately, because of the way that it links UKHLS data to ASC spending, we are unable to make that dataset publicly available. Please contact the relevant authors of that paper for replication materials, including relevant licenses from the UK Data Service. This notebook, however, should give you an example of how it works.
#
# A discussion question: how close are the estimates from RobustiPy to their results for the coefficient on LA ASC Spending in Table AI, for example?

# %% [markdown]
# First, lets load in the libraries we might need, as always:

# %%
import os
from robustipy.utils import prepare_union, prepare_asc
import matplotlib.pyplot as plt
from robustipy.models import OLSRobust

# %% [markdown]
# Now, call the helper function in the `robustipy.utils` module (Note: this is subject to change!). We have again put data at somewhere like `./data/input/`, similar to the other examples.

# %%
y, z, x, g, data = prepare_asc(os.path.join('..',
                                            'data',
                                            'asc_example',
                                            'CleanData_LASpending.dta'))

# %% [markdown]
# Importantly, we want our 'grouping' variable for the longitudinal analysis to be a 'string variable':

# %%
data[g] = data[g].astype(str)

# %% [markdown]
# Lets see what we have in this dataset as a result of the `prepare_asc()` function:

# %%
data.columns
# Out:
# Index([  'wellbeing_kikert',            'lrealgs', 'dcareNew*c.lrealgs',
#                  'dcareNew',                 'DR',               'lgva',
#                     'Mtotp',             'ddgree',                'age',
#                      2005.0,               2006.0,               2007.0,
#                      2009.0,               2010.0,               2011.0,
#                      2012.0,               2013.0,               2014.0,
#                      2015.0,               2016.0,               2017.0,
#                      2018.0,            'married',            'widowed',
#                   'disable',        'lrealtinc_m',    'house_ownership',
#                    'hhsize',               'work',            'retired',
#                      'pidp'],
#       dtype='object')

# %% [markdown]
# OK, so clearly a lot of variables here. Lets make sure that our time fixed effects are integers, as opposed to floats. Why do we not have a year for 2008?

# %%
for year in range(2005, 2019):
    if year!= 2008:
        data[float(year)] = data[float(year)].astype(int)
data.columns = data.columns.astype(str)

# %%
for i in range(len(x)):
    try:
        # Attempt to convert to integer
        x[i] = float(x[i])
        x[i] = str(x[i])
    except ValueError:
        # If invalid for int conversion, just store its string representation
        x[i] = str(x[i])
data['pidp'] = data['pidp'].astype(int)
print(x)
# Out:
# ['lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR', 'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0', '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0', '2016.0', '2017.0', '2018.0']

# %% [markdown]
# Lets now eyeball our data in two important ways. First, by taking the 'head' of it:

# %%
data.head(5)
# Out:
#    wellbeing_kikert    lrealgs  dcareNew*c.lrealgs  dcareNew        DR  \
# 0               6.0  11.475444            0.000000       0.0  0.580409
# 1              11.0  12.017206            0.000000       0.0  0.589392
# 2              12.0  10.861205            0.000000       0.0  0.602811
# 3              10.0  11.302839           11.302839       1.0  0.567938
# 4               7.0  12.484859            0.000000       0.0  0.505666
#
#         lgva     Mtotp  ddgree   age  2005.0  ...  2018.0  married  widowed  \
# 0   8.547691  0.306171     0.0  53.0       0  ...       0      0.0      0.0
# 1   9.062510  0.484650     1.0  58.0       0  ...       0      0.0      0.0
# 2   7.963520  0.158542     0.0  56.0       0  ...       0      1.0      0.0
# 3   8.274160  0.193195     1.0  71.0       0  ...       0      1.0      0.0
# 4  10.017715  0.723042     1.0  26.0       0  ...       0      0.0      0.0
#
#    disable  lrealtinc_m  house_ownership  hhsize  work  retired       pidp
# 0      0.0     6.947987              0.0       2   1.0      0.0  544608605
# 1      0.0     8.124743              1.0       1   1.0      0.0  340862245
# 2      0.0     5.979202              1.0       2   1.0      0.0  748912565
# 3      0.0     8.367115              1.0       2   1.0      0.0  748926165
# 4      0.0     8.006728              1.0       2   1.0      0.0  410088289
#
# [5 rows x 31 columns]

# %% [markdown]
# Then, by looking at the correlation matrix of it:

# %%
data.corr()
# Out:
#                     wellbeing_kikert   lrealgs  dcareNew*c.lrealgs  dcareNew  \
# wellbeing_kikert            1.000000  0.021962            0.056423  0.056078
# lrealgs                     0.021962  1.000000            0.031893  0.011635
# dcareNew*c.lrealgs          0.056423  0.031893            1.000000  0.998871
# dcareNew                    0.056078  0.011635            0.998871  1.000000
# DR                         -0.007103 -0.032193            0.035267  0.035652
# lgva                        0.005124  0.676267           -0.001630 -0.015768
# Mtotp                       0.018190  0.902588            0.033313  0.014199
# ddgree                     -0.045369 -0.002263           -0.057484 -0.057258
# age                        -0.007697 -0.025727            0.103288  0.104079
# 2005.0                      0.002999 -0.005191           -0.011956 -0.011756
# 2006.0                      0.002434 -0.000747           -0.009749 -0.009481
# 2007.0                      0.000979  0.000661            0.002118  0.002298
# 2009.0                      0.001482  0.008340           -0.004904 -0.005113
# 2010.0                      0.006098  0.019708            0.000346 -0.000163
# 2011.0                      0.005093  0.035446            0.007442  0.006486
# 2012.0                      0.001169  0.016794            0.006455  0.005921
# 2013.0                     -0.000804 -0.001862            0.006203  0.006354
# 2014.0                     -0.007266 -0.019708            0.005109  0.005356
# 2015.0                     -0.007511 -0.024302            0.003970  0.004601
# 2016.0                     -0.002282 -0.022338           -0.008066 -0.007461
# 2017.0                      0.001016 -0.002086           -0.007828 -0.007681
# 2018.0                      0.003674  0.010175            0.003925  0.003511
# married                    -0.059293 -0.002466            0.020580  0.020604
# widowed                     0.009764  0.004284           -0.032895 -0.032961
# disable                     0.218854  0.013158            0.073241  0.073060
# lrealtinc_m                -0.062148 -0.033330           -0.026760 -0.025949
# house_ownership            -0.096179 -0.033724            0.022502  0.022724
# hhsize                     -0.010190  0.034348            0.018442  0.017098
# work                       -0.116511 -0.032636           -0.066099 -0.065359
# retired                    -0.039451 -0.007989            0.046951  0.047280
# pidp                        0.000879  0.006766            0.010321  0.010270
#
#                           DR      lgva     Mtotp    ddgree       age  \
# wellbeing_kikert   -0.007103  0.005124  0.018190 -0.045369 -0.007697
# lrealgs            -0.032193  0.676267  0.902588 -0.002263 -0.025727
# dcareNew*c.lrealgs  0.035267 -0.001630  0.033313 -0.057484  0.103288
# dcareNew            0.035652 -0.015768  0.014199 -0.057258  0.104079
# lgva               -0.043643  0.044408
# Mtotp              -0.004977  0.039416
# ddgree             -0.135265  0.038600
# age                 0.717308 -0.005464
# 2005.0             -0.008866 -0.137190
# 2006.0             -0.005880 -0.133436
# 2007.0             -0.001990 -0.123202
# 2009.0             -0.010460 -0.163955
# 2010.0             -0.011955  0.041730
# 2011.0             -0.002592  0.029840
# 2012.0             -0.001859  0.027168
# 2013.0              0.004188  0.008358
# 2014.0              0.016580  0.021448
# 2015.0              0.017612  0.016188
# 2016.0              0.003583  0.096007
# 2017.0             -0.005419  0.249959
# 2018.0             -0.003676  0.026041
# married            -0.226401  0.050316
# widowed             0.358373 -0.009021
# disable             0.265820  0.032552
# lrealtinc_m        -0.103636 -0.001849
# house_ownership     0.128252 -0.053361
# hhsize             -0.354297  0.035090
# work               -0.608124 -0.010338
# retired             1.000000 -0.012379
# pidp               -0.012379  1.000000
#
# [31 rows x 31 columns]

# %% [markdown]
# Lets refresh a bit our memory of what y, x, c, and now g are:

# %%
print(y)
print(x)
print(z)
print(g)
print(data.columns)
# Out:
# wellbeing_kikert
# ['lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR', 'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0', '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0', '2016.0', '2017.0', '2018.0']
# ['married', 'widowed', 'disable', 'lrealtinc_m', 'house_ownership', 'hhsize', 'work', 'retired']
# pidp
# Index(['wellbeing_kikert', 'lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR',
#        'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0',
#        '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0',
#        '2016.0', '2017.0', '2018.0', 'married', 'widowed', 'disable',
#        'lrealtinc_m', 'house_ownership', 'hhsize', 'work', 'retired', 'pidp'],
#       dtype='object')

# %% [markdown]
# That's right! They're strings and lists! Now, lets call our OLSRobust model, just like before. Note, we don't specify the important parametres for our 'fitting' yet, and that's the bit that takes the most computational time, next up. What is different about our 'x' here, to the things that we've seen before?

# %%
myrobust_panel = OLSRobust(y=[y], x=x, data=data.reset_index())

# %% [markdown]
# Next, actually fit the model:

# %%
myrobust_panel.fit(controls=z,
                   draws=1000,
                   kfold=10,
                   seed=192735,
                   oos_metric='pseudo-r2',
                   group=g)
# Out:
# You haven’t specified the number of CPUs. Is 31 okay? (yes/no):  yes
# OLSRobust is running with n_cpu=31, draws=1000, folds=10, seed=192735.
# We're evaluating our out-of-sample predictions with the pseudo-r2 metric.
# The estimand of interest is lrealgs. Let's begin the calculations...
# Total model runs: 256,000 (draws=1000, control_specs=256, y_composites=1)
# /home/jinx/anaconda3/lib/python3.12/site-packages/robustipy/models.py:1845: UserWarning: [OLSRobust] Group fixed effects requested: dropping constant term before demeaning so t/p are identified.
#   warnings.warn(
# Bootstrap draws:   0.0%|          | 0/256000 [00:00<?, ?draw/s]

# %% [markdown]
# And then, grab our results from it:

# %%
asc_results = myrobust_panel.get_results()

# %% [markdown]
# Lets do some hopefully by now familiar things with it. First, lets have a look at the `summary_df` object, to check that everything feels right:

# %%
asc_results.summary_df
# Out:
#        median       max       min     ci_up   ci_down        r2        ll  \
# 0    0.228495  0.836225 -0.399703  0.629952 -0.152058  0.000577  0.000379
# 1    0.218530  0.822680 -0.411022  0.623177 -0.159167  0.000803  0.000497
# 2    0.224652  0.834894 -0.408788  0.625372 -0.160865  0.000683  0.000437
# 3    0.215092  0.821995 -0.427099  0.616211 -0.161293  0.004519  0.002360
# 4    0.228116  0.837044 -0.403872  0.630908 -0.152454  0.001255  0.000723
# ..        ...       ...       ...       ...       ...       ...       ...
# 251  0.184553  0.782011 -0.461535  0.587627 -0.193730  0.009099  0.004693
# 252  0.195512  0.792718 -0.439680  0.590989 -0.191924  0.005435  0.002848
# 253  0.185804  0.781592 -0.459496  0.587134 -0.192214  0.009139  0.004713
# 254  0.188647  0.789499 -0.459499  0.594496 -0.190511  0.009084  0.004685
# 255  0.185509  0.782823 -0.462261  0.588922 -0.192010  0.009162  0.004729
#
#                aic            bic           hqic         ll_raw  \
# 0    584697.098535  584898.907344  584758.076736 -292327.549268
# 1    584673.199885  584884.618637  584737.081809 -292314.599942
# 2    584686.411132  584897.829884  584750.293056 -292321.205566
# 3    584262.675147  584474.093899  584326.557071 -292109.337573
# 4    584623.301500  584834.720252  584687.183424 -292289.650750
# ..             ...            ...            ...            ...
# 251  583760.536607  584029.615019  583841.840874 -291852.268304
# 252  584167.153378  584436.231789  584248.457645 -292055.576689
# 253  583756.024031  584025.102443  583837.328298 -291850.012016
# 254  583762.189141  584031.267552  583843.493408 -291853.094570
# 255  583754.522161  584033.210516  583838.730152 -291848.261081
#
#            ll_null     ll_gain  ll_gain_per_obs    nobs  av_k_metric  \
# 0   -292369.348597   41.799329         0.000379  110188     0.000124
# 1   -292369.348597   54.748655         0.000497  110188     0.000319
# 2   -292369.348597   48.143031         0.000437  110188     0.000196
# 3   -292369.348597  260.011024         0.002360  110188     0.004063
# 4   -292369.348597   79.697847         0.000723  110188     0.000765
# ..             ...         ...              ...     ...          ...
# 251 -292369.348597  517.080294         0.004693  110188     0.008434
# 252 -292369.348597  313.771908         0.002848  110188     0.004761
# 253 -292369.348597  519.336581         0.004713  110188     0.008511
# 254 -292369.348597  516.254027         0.004685  110188     0.008455
# 255 -292369.348597  521.087516         0.004729  110188     0.008480
#
#                                              spec_name                 y
# 0                                                   ()  wellbeing_kikert
# 1                                            (married)  wellbeing_kikert
# 2                                            (widowed)  wellbeing_kikert
# 3                                            (disable)  wellbeing_kikert
# 4                                        (lrealtinc_m)  wellbeing_kikert
# ..                                                 ...               ...
# 251  (married, hhsize, disable, house_ownership, wi...  wellbeing_kikert
# 252  (married, hhsize, house_ownership, widowed, re...  wellbeing_kikert
# 253  (married, hhsize, disable, house_ownership, re...  wellbeing_kikert
# 254  (hhsize, disable, house_ownership, widowed, re...  wellbeing_kikert
# 255  (married, hhsize, disable, house_ownership, wi...  wellbeing_kikert
#
# [256 rows x 18 columns]

# %% [markdown]
# Then, lets plot the results from it:

# %%
asc_results.plot(
    specs=[['married'],
           ['widowed', 'disable'],
          ],
    ic='hqic',
    ci=0.95,
    ext='pdf',
    project_name='asc_example',
    figpath = '../figures/',
    figsize=(16, 16)
)

# %% [markdown]
# Finally, lets print out our logging, to get even more information:

# %%
asc_results.summary(digits=4)
# Out:
# ==============================
# 1. Model Summary
# ==============================
# Model: OLS Robust
# Inference Tests: Yes
# Dependent variable: wellbeing_kikert
# Independent variable: lrealgs
# Number of possible controls: 8
# Number of draws: 1000
# Number of folds: 10
# Number of specifications: 256
# ==============================
# 2. Model Robustness Metrics
# ==============================
# 2.1 Inference Metrics
# ==============================
# Median β (specs, no resampling): 0.2016 (null-calibrated p: 0.336)
# Median β (bootstraps × specs): 0.2069
# Min β (specs, no resampling): 0.1720
# Min β (bootstraps × specs): -0.4623
# Max β (specs, no resampling): 0.2379
# Max β (bootstraps × specs): 0.8514
# AIC-weighted β (specs, no resampling): 0.1825
# BIC-weighted β (specs, no resampling): 0.1818
# HQIC-weighted β (specs, no resampling): 0.1826
# Share significant (specs, no resampling) [descriptive]: 0.0000
# Share significant (bootstraps × specs) [descriptive]: 0.3186  |  null-calibrated p: 0.001998
# Share β>0 (specs, no resampling) [descriptive]: 1.0000
# Share β>0 (bootstraps × specs) [descriptive]: 0.8246  |  null-calibrated p: 0.9171
# Share β<0 (specs, no resampling) [descriptive]: 0.0000
# Share β<0 (bootstraps × specs) [descriptive]: 0.1754  |  null-calibrated p: 0.9171
# Share β>0 & significant (specs, no resampling) [descriptive]: 0.0000
# Share β>0 & significant (bootstraps × specs) [descriptive]: 0.3132  |  null-calibrated p: 0.001998
# Share β<0 & significant (specs, no resampling) [descriptive]: 0.0000
# Share β<0 & significant (bootstraps × specs) [descriptive]: 0.0054  |  null-calibrated p: 0.001998
# Stouffer’s Z = 1.3309  (two-sided p = 0.3277)
# ==============================
# 2.2 In-Sample Metrics (Full Sample)
# ==============================
# Min AIC: 583750.6172, Specs: ['married', 'disable', 'widowed', 'retired', 'work', 'lrealtinc_m']
# Min BIC: 583998.0849, Specs: ['married', 'work', 'disable', 'retired']
# Min HQIC: 583827.6522, Specs: ['married', 'disable', 'retired', 'work', 'lrealtinc_m']
# Max Relative Log-Likelihood Gain (per obs): 0.0047, Specs: ['married', 'hhsize', 'disable', 'house_ownership', 'widowed', 'retired', 'work', 'lrealtinc_m']
# Min Relative Log-Likelihood Gain (per obs): 0.0004, Specs: []
# Max Raw Log Likelihood: -291848.2611, Specs: ['married', 'hhsize', 'disable', 'house_ownership', 'widowed', 'retired', 'work', 'lrealtinc_m']
# Min Raw Log Likelihood: -292327.5493, Specs: []
# Max Adj-R²: 0.0092, Specs: ['married', 'disable', 'widowed', 'retired', 'work', 'lrealtinc_m']
# Min Adj-R²: 0.0006, Specs: ['hhsize', 'house_ownership']
# ==============================
# 2.3 Out-Of-Sample Metrics (pseudo-r2 averaged across folds)
# ==============================
# Max Average: 0.0086, Specs: ['married', 'disable', 'retired', 'work', 'lrealtinc_m']
# Min Average: 0.0001, Specs: ['hhsize', 'house_ownership']
# Mean Average: 0.0041
# Median Average: 0.0047
