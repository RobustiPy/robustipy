# %%
import os # for filepath handling
import pandas as pd
import requests # for grabbing the dataset
import matplotlib.pyplot as plt # for plotting
from robustipy.models import OLSRobust

# %% [markdown]
# Create a wrapper to grab the data:

# %%
def get_data():
    uscrime_path = os.path.join('data', 'input', 'uscrime.txt')
    if os.path.exists(uscrime_path):
        df = pd.read_csv(uscrime_path, sep=r"\s+")
    else:
        df = pd.read_csv("https://fermin.perso.math.cnrs.fr/Files/UScrime.txt",
                         sep=r"\s+", skiprows=35, index_col=0)
        df.to_csv(uscrime_path, sep='\t')
    df = df.rename({'M': 'Males',
                    'LF': 'Labour Force',
                    'W': 'Wealth',
                    'X': 'Inequality',
                    'U1': 'Unemployment',
                    'Ex0': 'Expenditure'}, axis=1)    
    return df

# %% [markdown]
# Get the data, and look at its header:

# %%
df = get_data()
df.head()
# Out:
#        R  Age   Ed  Expenditure  Ex1  Labour Force  Males    N   NW  \
# 0   79.1  151   91           58   56           510    950   33  301
# 1  163.5  143  113          103   95           583   1012   13  102
# 2   57.8  142   89           45   44           533    969   18  219
# 3  196.9  136  121          149  141           577    994  157   80
# 4  123.4  141  121          109  101           591    985   18   30
#
#    Unemployment  U2  Wealth  Inequality
# 0           108  41     394         261
# 1            96  36     557         194
# 2            94  33     318         250
# 3           102  39     673         167
# 4            91  20     578         174

# %% [markdown]
# Do some RobustiPy things:

# %%
ehrlich_robust = OLSRobust(y=['R'], x=['Inequality'], data=df)
ehrlich_robust.fit(controls=['Expenditure',
                             'Age',
                             'Ed',
                             'Unemployment',
                             'Males',
                             'N',
                             'Wealth'],
                   draws=1000,
                   kfold=10,
                   seed=192735,
                  )
# Out:
# Output()
# [OLSRobust] Running with n_cpu=31, draws=1000
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# Get the results:

# %%
ehrlich_results = ehrlich_robust.get_results()

# %% [markdown]
# Plot them:

# %%
ehrlich_results.plot(specs=[['Ed', 'N'],
                            ['Age', 'Males', 'Wealth']],
                     ic='hqic',
                     ci=1,
                     ext='pdf',
                     project_name='erlich_example',
                     figsize=(16, 16)
                    )

# %% [markdown]
# Summarize them (with six digits):

# %%
ehrlich_results.summary(digits=6)
# Out:
# ==============================
# 1. Model Summary
# ==============================
# Model: OLS Robust
# Inference Tests: Yes
# Dependent variable: R
# Independent variable: Inequality
# Number of possible controls: 7
# Number of draws: 1000
# Number of folds: 10
# Number of specifications: 128
# ==============================
# 2.Model Robustness Metrics
# ==============================
# 2.1 Inference Metrics
# ==============================
# Median beta (all specifications, no resampling): 0.697595 (p-value: 0.0)
# Median beta (all bootstraps and specifications): 0.616036
# Min beta (all specifications, no resampling): -0.230406
# Min beta (all bootstraps and specifications): -0.928366
# Max beta (all specifications, no resampling): 1.085075
# Max beta (all bootstraps and specifications): 2.107815
# AIC-weighted beta (all specifications, no resampling): 0.811604
# BIC-weighted beta (all specifications, no resampling): 0.729611
# HQIC-weighted beta (all specifications, no resampling): 0.7588
# Significant portion of beta (all specifications, no resampling): 0.75 (p-value: 0.0)
# Significant portion of beta (all bootstraps and specifications): 0.733562
# Positive portion of beta (all specifications, no resampling): 0.875 (p-value: 0.0)
# Positive portion of beta (all bootstraps and specifications): 0.862219
# Negative portion of beta (all specifications, no resampling): 0.125 (p-value: 1.0)
# Negative portion of beta (all bootstraps and specifications): 0.137781
# Positive and Significant portion of beta (all specifications, no resampling): 0.75 (p-value: 0.0)
# Positive and Significant portion of beta (all bootstraps and specifications): 0.717289
# Negative and Significant portion of beta (all specifications, no resampling): 0.0 (p-value: 0.976)
# Negative and Significant portion of beta (all bootstraps and specifications): 0.016273
# Stouffer's Z-score test: 28.205161, 0.0
# ==============================
# 2.2 In-Sample Metrics (Full Sample)
# ==============================
# Min AIC: 507.543171, Specs: ['Wealth', 'Expenditure', 'Unemployment', 'Age', 'N', 'Ed', 'Males']
# Min BIC: 438.527171, Specs: ['Ed', 'Wealth', 'Expenditure', 'Age']
# Min HQIC: 431.603623, Specs: ['Ed', 'Wealth', 'Expenditure', 'Age']
# Max Log Likelihood: -206.771585, Specs: ['Wealth', 'Expenditure', 'Unemployment', 'Age', 'N', 'Ed', 'Males']
# Min Log Likelihood: -237.214851, Specs: []
# Max Adj- R2: 0.69218, Specs: ['Wealth', 'Expenditure', 'Age', 'Ed', 'Males']
# Min Adj- R2: -0.031013, Specs: ['Unemployment', 'Age']
# ==============================
# 2.3 Out-Of-Sample Metrics (r-squared averaged across folds)
# ==============================
# Max Average: 0.418465, Specs: ['Ed', 'Unemployment', 'Expenditure', 'Age']
# Min Average: -0.751368, Specs: ['Ed', 'Unemployment', 'Age', 'Males']
# Mean Average: -0.060055
# Median Average: 0.019559
