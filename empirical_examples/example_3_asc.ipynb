# %% [markdown]
# ### Empirical Example Four for RobustiPy!
#
# #### This example is designed to show how the OLSRobust class can be used to estimate a model with longitudinal data _and_ a set of specific, constant x-variables.
#
# Specifically, it represents an Adult Social Care (ASC) example from Zhang, Bennett and Yeandle published in the BMJ Open. You can find that paper [here](https://bmjopen.bmj.com/content/11/12/e049652). Unfortunately, because of the way that it links UKHLS data to ASC spending, we are unable to make that dataset publicly available. This notebook, however, should give you an example of how it works.
#
# A discussion question: how close are the estimates from RobustiPy to their results for the coefficient on LA ASC Spending in Table AI, for example?

# %% [markdown]
# First, lets load in the libraries we might need, as always:

# %%
import os
from robustipy.utils import prepare_union, prepare_asc
import matplotlib.pyplot as plt
from robustipy.models import OLSRobust

# %% [markdown]
# Now, call the helper function in the `robustipy.utils` module (Note: this is subject to change!). We have again put data at somewhere like `./data/input/`, similar to the other examples.

# %%
y, c, x, g, data = prepare_asc(os.path.join('data',
                                            'input',
                                            'CleanData_LASpending.dta'))

# %% [markdown]
# Importantly, we want our 'grouping' variable for the longitudinal analysis to be a 'string variable':

# %%
data[g] = data[g].astype(str)

# %% [markdown]
# Lets see what we have in this dataset as a result of the `prepare_asc()` function:

# %%
data.columns
# Out:
# Index([  'wellbeing_kikert',            'lrealgs', 'dcareNew*c.lrealgs',
#                  'dcareNew',                 'DR',               'lgva',
#                     'Mtotp',             'ddgree',                'age',
#                      2005.0,               2006.0,               2007.0,
#                      2009.0,               2010.0,               2011.0,
#                      2012.0,               2013.0,               2014.0,
#                      2015.0,               2016.0,               2017.0,
#                      2018.0,            'married',            'widowed',
#                   'disable',        'lrealtinc_m',    'house_ownership',
#                    'hhsize',               'work',            'retired',
#                      'pidp'],
#       dtype='object')

# %% [markdown]
# OK, so clearly a lot of variables here. Lets make sure that our time fixed effects are integers, as opposed to floats. Why do we not have a year for 2008?

# %%
for year in range(2005, 2019):
    if year!= 2008:
        data[float(year)] = data[float(year)].astype(int)
data.columns = data.columns.astype(str)

# %%
for i in range(len(x)):
    try:
        # Attempt to convert to integer
        x[i] = float(x[i])
        x[i] = str(x[i])
    except ValueError:
        # If invalid for int conversion, just store its string representation
        x[i] = str(x[i])
print(x)
# Out:
# ['lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR', 'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0', '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0', '2016.0', '2017.0', '2018.0']

# %% [markdown]
# Lets now eyeball our data in two important ways. First, by taking the 'head' of it:

# %%
data.head(5)
# Out:
#    wellbeing_kikert    lrealgs  dcareNew*c.lrealgs  dcareNew        DR  \
# 0               6.0  11.475444            0.000000       0.0  0.580409
# 1              11.0  12.017206            0.000000       0.0  0.589392
# 2              12.0  10.861205            0.000000       0.0  0.602811
# 3              10.0  11.302839           11.302839       1.0  0.567938
# 4               7.0  12.484859            0.000000       0.0  0.505666
#
#         lgva     Mtotp  ddgree   age  2005.0  ...  2018.0  married  widowed  \
# 0   8.547691  0.306171     0.0  53.0       0  ...       0      0.0      0.0
# 1   9.062510  0.484650     1.0  58.0       0  ...       0      0.0      0.0
# 2   7.963520  0.158542     0.0  56.0       0  ...       0      1.0      0.0
# 3   8.274160  0.193195     1.0  71.0       0  ...       0      1.0      0.0
# 4  10.017715  0.723042     1.0  26.0       0  ...       0      0.0      0.0
#
#    disable  lrealtinc_m  house_ownership  hhsize  work  retired       pidp
# 0      0.0     6.947987              0.0       2   1.0      0.0  544608605
# 1      0.0     8.124743              1.0       1   1.0      0.0  340862245
# 2      0.0     5.979202              1.0       2   1.0      0.0  748912565
# 3      0.0     8.367115              1.0       2   1.0      0.0  748926165
# 4      0.0     8.006728              1.0       2   1.0      0.0  410088289
#
# [5 rows x 31 columns]

# %% [markdown]
# Then, by looking at the correlation matrix of it:

# %%
data.corr()
# Out:
#                     wellbeing_kikert   lrealgs  dcareNew*c.lrealgs  dcareNew  \
# wellbeing_kikert            1.000000  0.019236            0.058915  0.058755
# lrealgs                     0.019236  1.000000            0.028417  0.009526
# dcareNew*c.lrealgs          0.058915  0.028417            1.000000  0.998937
# dcareNew                    0.058755  0.009526            0.998937  1.000000
# DR                         -0.005181 -0.090032            0.031812  0.033001
# lgva                        0.002526  0.653079            0.002260 -0.011206
# Mtotp                       0.015688  0.898583            0.030591  0.012692
# ddgree                     -0.044843 -0.000497           -0.050027 -0.049650
# age                         0.003294 -0.029748            0.103296  0.104201
# 2005.0                      0.003546 -0.004848           -0.007538 -0.007257
# 2006.0                      0.002916  0.001257           -0.004530 -0.004110
# 2007.0                     -0.000960 -0.001603            0.004861  0.005298
# 2009.0                      0.000736  0.027787           -0.004853 -0.005347
# 2010.0                      0.006041  0.031838           -0.004414 -0.004209
# 2011.0                      0.005561  0.031324            0.002802  0.001786
# 2012.0                      0.004499  0.006640            0.004304  0.004149
# 2013.0                      0.002082 -0.004503            0.005364  0.005273
# 2014.0                     -0.006059 -0.023192            0.005557  0.005662
# 2015.0                     -0.012495 -0.031086            0.005119  0.005559
# 2016.0                     -0.000285 -0.024762           -0.005325 -0.004934
# 2017.0                     -0.003277 -0.007280           -0.006772 -0.006636
# 2018.0                      0.003380  0.003819            0.000161 -0.000102
# married                    -0.059685 -0.001582            0.015376  0.015346
# widowed                     0.014160  0.002085           -0.033811 -0.033388
# disable                     0.221801  0.006956            0.073540  0.073273
# lrealtinc_m                -0.057263 -0.036607           -0.025843 -0.024590
# house_ownership            -0.090803 -0.043963            0.017994  0.018746
# hhsize                     -0.016184  0.043252            0.001912  0.000564
# work                       -0.109062 -0.036149           -0.058616 -0.057492
# retired                    -0.037837 -0.013873            0.053040  0.053394
# pidp                       -0.002745  0.008702            0.000322  0.000585
#
#                           DR      lgva     Mtotp    ddgree       age  \
# wellbeing_kikert   -0.005181  0.002526  0.015688 -0.044843  0.003294
# lrealgs            -0.090032  0.653079  0.898583 -0.000497 -0.029748
# dcareNew*c.lrealgs  0.031812  0.002260  0.030591 -0.050027  0.103296
# dcareNew            0.033001 -0.011206  0.012692 -0.049650  0.104201
# DR                  1.000000 -0.377799  0.029081 -0.103813  0.132242
# lgva               -0.377799  1.000000  0.634814  0.037017 -0.066386
# Mtotp               0.029081  0.634814  1.000000 -0.009123 -0.022032
# ddgree             -0.103813  0.037017 -0.009123  1.000000 -0.088949
# 2015.0              0.000167  0.063385
# 2016.0              0.003598  0.091672
# 2017.0             -0.007221  0.227317
# 2018.0             -0.004056  0.026549
# married            -0.243827  0.059539
# widowed             0.372017 -0.012051
# disable             0.285035  0.018557
# lrealtinc_m        -0.100182 -0.014838
# house_ownership     0.121491 -0.081381
# hhsize             -0.344404  0.070408
# work               -0.535800 -0.028219
# retired             1.000000 -0.023926
# pidp               -0.023926  1.000000
#
# [31 rows x 31 columns]

# %% [markdown]
# Lets refresh a bit our memory of what y, x, c, and now g are:

# %%
print(y)
print(x)
print(c)
print(g)
print(data.columns)
# Out:
# wellbeing_kikert
# ['lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR', 'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0', '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0', '2016.0', '2017.0', '2018.0']
# ['married', 'widowed', 'disable', 'lrealtinc_m', 'house_ownership', 'hhsize', 'work', 'retired']
# pidp
# Index(['wellbeing_kikert', 'lrealgs', 'dcareNew*c.lrealgs', 'dcareNew', 'DR',
#        'lgva', 'Mtotp', 'ddgree', 'age', '2005.0', '2006.0', '2007.0',
#        '2009.0', '2010.0', '2011.0', '2012.0', '2013.0', '2014.0', '2015.0',
#        '2016.0', '2017.0', '2018.0', 'married', 'widowed', 'disable',
#        'lrealtinc_m', 'house_ownership', 'hhsize', 'work', 'retired', 'pidp'],
#       dtype='object')

# %% [markdown]
# That's right! They're strings and lists! Now, lets call our OLSRobust model, just like before. Note, we don't specify the important parametres for our 'fitting' yet, and that's the bit that takes the most computational time, next up. What is different about our 'x' here, to the things that we've seen before?

# %%
data = data.dropna()
myrobust_panel = OLSRobust(y=[y], x=x, data=data.reset_index())

# %% [markdown]
# Next, actually fit the model:

# %%
myrobust_panel.fit(controls=c,
                   draws=1000,
                   kfold=10,
                   group=g)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# And then, grab our results from it:

# %%
asc_results = myrobust_panel.get_results()

# %% [markdown]
# Lets do some hopefully by now familiar things with it. First, lets have a look at the `summary_df` object, to check that everything feels right:

# %%
asc_results.summary_df
# Out:
#        median       max       min     ci_up   ci_down        r2  \
# 0    0.228583  0.322121  0.092659  0.293599  0.159389  0.000568
# 1    0.217869  0.303005  0.086128  0.279370  0.150906  0.000794
# 2    0.220277  0.322373  0.102686  0.287092  0.155392  0.000674
# 3    0.211985  0.311586  0.095259  0.276147  0.146974  0.004510
# 4    0.226173  0.335857  0.109365  0.290320  0.165340  0.001246
# ..        ...       ...       ...       ...       ...       ...
# 251  0.183025  0.272334  0.067159  0.242010  0.119126  0.009090
# 252  0.195462  0.299673  0.064292  0.252133  0.123212  0.005426
# 253  0.183952  0.270114  0.073595  0.245303  0.116166  0.009130
# 254  0.182151  0.299155  0.065565  0.247396  0.126522  0.009075
# 255  0.184189  0.306530  0.077202  0.251639  0.114668  0.009153
#
#                 ll            aic            bic           hqic  av_k_metric  \
# 0   -292327.549268  805031.098535  584910.517288  584762.980459     0.000166
# 1   -292314.599942  805005.199885  584896.228580  584741.985532     0.000373
# 2   -292321.205566  805018.411132  584909.439828  584755.196780     0.000247
# 3   -292109.337573  804594.675147  584485.703842  584331.460795     0.003970
# 4   -292289.650750  804955.301500  584846.330195  584692.087148     0.000820
# ..             ...            ...            ...            ...          ...
# 251 -291852.268304  804080.536607  584041.224962  583846.744598     0.008401
# 252 -292055.576689  804487.153378  584447.841733  584253.361369     0.004834
# 253 -291850.012016  804076.024031  584036.712387  583842.232022     0.008445
# 254 -291853.094570  804082.189141  584042.877496  583848.397131     0.008382
# 255 -291848.261081  804072.522161  584044.820460  583843.633876     0.008425
#
#                                              spec_name                 y
# 0                                                   ()  wellbeing_kikert
# 1                                            (married)  wellbeing_kikert
# 2                                            (widowed)  wellbeing_kikert
# 3                                            (disable)  wellbeing_kikert
# 4                                        (lrealtinc_m)  wellbeing_kikert
# ..                                                 ...               ...
# 251  (house_ownership, work, widowed, married, hhsi...  wellbeing_kikert
# 252  (house_ownership, work, widowed, married, lrea...  wellbeing_kikert
# 253  (house_ownership, work, married, lrealtinc_m, ...  wellbeing_kikert
# 254  (house_ownership, work, widowed, lrealtinc_m, ...  wellbeing_kikert
# 255  (house_ownership, work, widowed, married, lrea...  wellbeing_kikert
#
# [256 rows x 13 columns]

# %% [markdown]
# Then, lets plot the results from it:

# %%
asc_results.plot(
    specs=[['married'],
           ['widowed', 'disable'],
           ['house_ownership', 'hhsize']
          ],
    ic='hqic',
    ext='pdf',
    project_name='asc_example',
    figsize=(16, 16)
)

# %% [markdown]
# Finally, lets print out our logging, to get even more information:

# %%
asc_results.summary()
# Out:
# ============================================================================================================
# 1. Model Summary
# ============================================================================================================
# Model: OLS Robust
# Dependent variable: wellbeing_kikert
# Independent variable: lrealgs
# Number of possible controls: 8
# Number of draws: 1000
# Number of folds: 10
# Number of specifications: 256
# ============================================================================================================
# 2.Model Robustness Metrics
# ============================================================================================================
# 2.1 Inference Metrics
# ------------------------------------------------------------------------------------------------------------
# Mean beta: 0.20
# Min beta: 0.17
# Max beta: 0.24
# Significant portion of beta: 0.00
# Positive portion of beta: 1.00
# Positive and Significant portion of beta: 0.00
# Negative and Significant portion of beta: 0.00
# ------------------------------------------------------------------------------------------------------------
# 2.1 In-Sample Metrics
# ------------------------------------------------------------------------------------------------------------
# Min AIC: 804072.5221613615,Specs: ['house_ownership', 'work', 'widowed', 'married', 'lrealtinc_m', 'hhsize', 'retired', 'disable']
# Min BIC: 584009.6948384331, Specs: ['retired', 'married', 'disable', 'work']
# Min HQIC: 583832.5558760737, Specs: ['work', 'married', 'lrealtinc_m', 'retired', 'disable']
# Max Log Likelihood: -291848.26108068076, Specs: ['house_ownership', 'work', 'widowed', 'married', 'lrealtinc_m', 'hhsize', 'retired', 'disable']
# Min Log Likelihood: -292327.5492677171, Specs: []
# Max R2: 0.009169955383832251, Specs: ['work', 'widowed', 'married', 'lrealtinc_m', 'retired', 'disable']
# Min R2: 0.0005499732434270932, Specs: ['house_ownership', 'hhsize']
# ------------------------------------------------------------------------------------------------------------
# 2.2 Out-Of-Sample Metrics (r-squared)
# ------------------------------------------------------------------------------------------------------------
# Max: 0.008512775220490954, Specs: ['work', 'married', 'lrealtinc_m', 'retired', 'disable']
# Min: 0.00010071405563262248, Specs: ['house_ownership', 'hhsize']
# Mean: 0.00
# Median: 0.00
